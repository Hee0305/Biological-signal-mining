# %% [markdown]
# <a href="https://colab.research.google.com/github/Hee0305/PDM06/blob/main/py-tensorflow/DL2-CNN/dl2_07_cifar10_CNN_Daug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CNN model of cifar10 dataset**
# - Conv2D + FCN
#     * Conv2D : 2차원 합성곱 필터링 + 풀링(Pooling)
#     - > 2차원 필터로 영상을 대표하는 특징을 추출
#     * FCN : 1차원 완전연결신경망
#     - > Conv2D에서 추출된 대표 특징들을 이용하여 FCN으로 최종 학습 완료
#     * **Data augmentation**
#
# ***
# - ## Traget: **Find the best model**
# ***
#
# ![cnn_c4f5.png](https://raw.githubusercontent.com/Redwoods/Py/master//pdm2020/my-note/py-tensorflow/images/cnn_c4f5.png)

# %% [markdown]
# ## Search the best model of C4F5
# - callback
#     - Early stopping
#     - model checkpoint
# - Data augmentation

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)
# Out:
# 2.7.0

# %%
# import TF2 submodules
from tensorflow.keras import layers, models, callbacks

# %% [markdown]
# ## **데이터 로딩, 정규화**

# %%
from keras.datasets import cifar10

(X_train0, y_train0), (X_test0, y_test0) = cifar10.load_data()

# Reshape
# X_train = X_train0.reshape(60000,28,28,1)
# X_test = X_test0.reshape(10000,28,28,1)

# Normalization
X_train, X_test = X_train0/255.0, X_test0/255.0 # 정규화

print("X_train={0}".format(X_train.shape))
print("y_train={0}".format(y_train0.shape)) 
print("X_test={0}".format(X_test.shape))
print("y_test={0}".format(y_test0.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step
# 170508288/170498071 [==============================] - 11s 0us/step
# X_train=(50000, 32, 32, 3)
# y_train=(50000, 1)
# X_test=(10000, 32, 32, 3)
# y_test=(10000, 1)

# %%
# One-Hot-Encoding
# Use function to_categorical() to do One-Hot-Encoding
# tf.keras.utils.to_categorical
from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train0, 10)
y_test = to_categorical(y_test0, 10)
y_train.shape,y_test.shape
# Out:
# ((50000, 10), (10000, 10))

# %%
# y_train0.shape vs. y_train.shape
y_train0.shape, y_train.shape
# Out:
# ((50000, 1), (50000, 10))

# %% [markdown]
# ### Display cifar10 data
# - one random image
# - 10 representative images

# %%
# Code here!
# display one random image from the training set:
class_names =  ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

idx = np.random.randint(0, X_train0.shape[0])
print(idx)
image = X_train0[idx]
plt.imshow(image) #, cmap=plt.get_cmap('gray'))
plt.title(class_names[y_train0[idx][0]])
plt.xticks([])
plt.yticks([])
plt.show()
# Out:
# 28939

# %%
fig = plt.figure(figsize=(10,6))
num0_9 = np.unique(y_train0, return_index=True)[1]
images = X_train[num0_9]
for i in range(10):
    plt.subplot(2, 5, i+1)
    # num0_9 = X_train0[y_train0 == i]
    
    # print(num0_9.shape)
    # plt.imshow(num0_9[0]) 
    plt.imshow(images[i])
    plt.title(class_names[i])
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## data augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
# data augmentation
# https://github.com/moritzhambach/Image-Augmentation-in-Keras-CIFAR-10-/blob/master/CNN%20with%20Image%20Augmentation%20(CIFAR10).ipynb
# set up image augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
    #zoom_range=0.3
    )
datagen.fit(X_train)

# %%
BATCH_SIZE = 50
for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=BATCH_SIZE):
    print(X_batch.shape, y_batch.shape)
    # create a grid of 5x10 images
    plt.figure(figsize=(13,13))
    for i in range(BATCH_SIZE):
        plt.subplot(5,10,i+1)
        plt.imshow(X_batch[i]) #, cmap=plt.get_cmap('gray'))
        plt.title(class_names[np.argmax(y_batch[i])])
        # show the plot
    plt.show()
    break
# Out:
# (50, 32, 32, 3) (50, 10)

# %% [markdown]
# # Design CNN

# %% [markdown]
# ### import models, layers, callbacks
# - models: Sequential
# - layers: Conv2D, MaxPool2D, Flatten
# - callbacks: ModelCheckpoint, EarlyStopping

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.callbacks import ModelCheckpoint, EarlyStopping, LearningRateScheduler, TensorBoard
from keras import regularizers, optimizers

# %%
# 모델 구성
num_classes = 10
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=X_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(128, activation='elu'))
model.add(Dense(num_classes, activation='softmax'))

# %%
opt_rms = keras.optimizers.RMSprop(learning_rate=0.001,decay=1e-6)

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)  # 5, 10, 20, 50

# %%
model.compile(loss='categorical_crossentropy',
        optimizer=opt_rms, # 'adam'
        metrics=['accuracy'])

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 68s 56ms/step - loss: 1.6071 - accuracy: 0.4600 - val_loss: 1.1966 - val_accuracy: 0.6210
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 1.1536 - accuracy: 0.6175 - val_loss: 1.7120 - val_accuracy: 0.5456
# Epoch 3/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 1.0269 - accuracy: 0.6724 - val_loss: 0.9640 - val_accuracy: 0.6991
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.9502 - accuracy: 0.7035 - val_loss: 0.9313 - val_accuracy: 0.7133
# Epoch 5/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.8937 - accuracy: 0.7265 - val_loss: 1.0808 - val_accuracy: 0.7036
# Epoch 6/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.8550 - accuracy: 0.7408 - val_loss: 0.8460 - val_accuracy: 0.7592
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.8251 - accuracy: 0.7550 - val_loss: 0.9737 - val_accuracy: 0.7301
# Epoch 8/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7971 - accuracy: 0.7680 - val_loss: 0.8295 - val_accuracy: 0.7695
# Epoch 9/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.7766 - accuracy: 0.7775 - val_loss: 0.7281 - val_accuracy: 0.7991
# Epoch 10/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7593 - accuracy: 0.7819 - val_loss: 0.7448 - val_accuracy: 0.7997
# Epoch 11/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.7407 - accuracy: 0.7902 - val_loss: 0.9762 - val_accuracy: 0.7282
# Epoch 12/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.7284 - accuracy: 0.7974 - val_loss: 0.6769 - val_accuracy: 0.8207
# Epoch 13/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.7190 - accuracy: 0.8012 - val_loss: 0.7655 - val_accuracy: 0.7955
# Epoch 14/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.7122 - accuracy: 0.8057 - val_loss: 0.7985 - val_accuracy: 0.7799
# Epoch 15/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.7007 - accuracy: 0.8088 - val_loss: 0.7066 - val_accuracy: 0.8109
# Epoch 16/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.6925 - accuracy: 0.8101 - val_loss: 0.7455 - val_accuracy: 0.8006
# Epoch 17/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.6863 - accuracy: 0.8124 - val_loss: 0.7110 - val_accuracy: 0.8137
# Epoch 00017: early stopping

# %%
model.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 3s 11ms/step - loss: 0.7110 - accuracy: 0.8137
# [0.7110494375228882, 0.8137000203132629]

# %% [markdown]
# ### cifar10 Daug best Model
# - cifar10_Daug_best_weights.013-0.8025.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_Daug_best_weights.012-0.8207.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.6769 - accuracy: 0.8207
# [0.6769005656242371, 0.8206999897956848]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_Daug_best

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # import models, layers, callbacks

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten
from keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# # **CNN1 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c1f3 = tf.keras.models.Sequential([ 
    # tf.keras.layers.Flatten(input_shape=(28, 28)), 
    Conv2D(input_shape=(32,32,3), filters= 32,
            kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),  
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Dense(128, activation='relu'),  
    tf.keras.layers.Dropout(0.25), 
    tf.keras.layers.Dense(10, activation='softmax')
])

cifar10_c1f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c1f3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 2,132,490
# Trainable params: 2,132,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c1f3_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10, 25, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 51s 50ms/step - loss: 0.7188 - accuracy: 0.7995 - val_loss: 0.6663 - val_accuracy: 0.8218
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.7140 - accuracy: 0.8031 - val_loss: 0.6778 - val_accuracy: 0.8185
# Epoch 3/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6985 - accuracy: 0.8090 - val_loss: 0.7045 - val_accuracy: 0.8112
# Epoch 4/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.6904 - accuracy: 0.8121 - val_loss: 0.7190 - val_accuracy: 0.8083
# Epoch 5/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.6856 - accuracy: 0.8134 - val_loss: 0.8265 - val_accuracy: 0.7893
# Epoch 6/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6761 - accuracy: 0.8188 - val_loss: 0.6781 - val_accuracy: 0.8263
# Epoch 7/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6729 - accuracy: 0.8213 - val_loss: 0.6650 - val_accuracy: 0.8285
# Epoch 8/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6590 - accuracy: 0.8220 - val_loss: 0.6749 - val_accuracy: 0.8252
# Epoch 9/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6527 - accuracy: 0.8247 - val_loss: 0.6536 - val_accuracy: 0.8371
# Epoch 10/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6526 - accuracy: 0.8248 - val_loss: 0.7664 - val_accuracy: 0.8080
# Epoch 11/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6459 - accuracy: 0.8306 - val_loss: 0.7438 - val_accuracy: 0.8080
# Epoch 12/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.6409 - accuracy: 0.8314 - val_loss: 0.6202 - val_accuracy: 0.8392
# Epoch 13/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.6362 - accuracy: 0.8328 - val_loss: 0.6426 - val_accuracy: 0.8377
# Epoch 14/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6298 - accuracy: 0.8358 - val_loss: 0.6007 - val_accuracy: 0.8526
# Epoch 15/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6262 - accuracy: 0.8364 - val_loss: 0.7077 - val_accuracy: 0.8215
# Epoch 16/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6256 - accuracy: 0.8393 - val_loss: 0.7021 - val_accuracy: 0.8188
# Epoch 17/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6232 - accuracy: 0.8384 - val_loss: 0.6120 - val_accuracy: 0.8477
# Epoch 18/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.6149 - accuracy: 0.8411 - val_loss: 0.6566 - val_accuracy: 0.8359
# Epoch 19/500
# 1000/1000 [==============================] - 48s 48ms/step - loss: 0.6159 - accuracy: 0.8411 - val_loss: 0.6197 - val_accuracy: 0.8447
# Epoch 00019: early stopping

# %%
cifar10_c1f3.evaluate(X_test, y_test, batch_size = 100)
# Out:
# 100/100 [==============================] - 1s 5ms/step - loss: 2.3091 - accuracy: 0.0789
# [2.3090670108795166, 0.07890000194311142]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar_c1f3

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### cifar10 C1F3 Best Model
# - cifar10_c1f3_best_weights.009-0.8384.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c1f3_best_weights.014-0.8526.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.6007 - accuracy: 0.8526
# [0.600678563117981, 0.8525999784469604]

# %% [markdown]
# ## **CNN2 + FCN2**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f2 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),kernel_size=(3,3),strides=(1,1),filters= 64,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(kernel_size=(3,3),strides=(1,1),filters= 32,padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f2.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)        1792
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 32)        18464
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 2048)              0
#
#  dense_7 (Dense)             (None, 128)               262272
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 283,818
# Trainable params: 283,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f2_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)    # patience=10, 20, 50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5653 - accuracy: 0.8589 - val_loss: 0.5782 - val_accuracy: 0.8613
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5597 - accuracy: 0.8607 - val_loss: 0.6301 - val_accuracy: 0.8426
# Epoch 3/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5604 - accuracy: 0.8606 - val_loss: 0.5812 - val_accuracy: 0.8628
# Epoch 4/500
# 1000/1000 [==============================] - 50s 49ms/step - loss: 0.5630 - accuracy: 0.8620 - val_loss: 0.5900 - val_accuracy: 0.8570
# Epoch 5/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5584 - accuracy: 0.8634 - val_loss: 0.5700 - val_accuracy: 0.8671
# Epoch 6/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5563 - accuracy: 0.8628 - val_loss: 0.5965 - val_accuracy: 0.8607
# Epoch 7/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5550 - accuracy: 0.8617 - val_loss: 0.5859 - val_accuracy: 0.8578
# Epoch 8/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5532 - accuracy: 0.8639 - val_loss: 0.6192 - val_accuracy: 0.8501
# Epoch 9/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5533 - accuracy: 0.8636 - val_loss: 0.6149 - val_accuracy: 0.8471
# Epoch 10/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5588 - accuracy: 0.8622 - val_loss: 0.5820 - val_accuracy: 0.8599
# Epoch 11/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5543 - accuracy: 0.8627 - val_loss: 0.7118 - val_accuracy: 0.8270
# Epoch 12/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5495 - accuracy: 0.8649 - val_loss: 0.6674 - val_accuracy: 0.8344
# Epoch 13/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5440 - accuracy: 0.8673 - val_loss: 0.5872 - val_accuracy: 0.8589
# Epoch 14/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5451 - accuracy: 0.8654 - val_loss: 0.5559 - val_accuracy: 0.8685
# Epoch 15/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5459 - accuracy: 0.8651 - val_loss: 0.6116 - val_accuracy: 0.8574
# Epoch 16/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5509 - accuracy: 0.8662 - val_loss: 0.5619 - val_accuracy: 0.8721
# Epoch 17/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5465 - accuracy: 0.8653 - val_loss: 0.5880 - val_accuracy: 0.8582
# Epoch 18/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5468 - accuracy: 0.8658 - val_loss: 0.6013 - val_accuracy: 0.8565
# Epoch 19/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5485 - accuracy: 0.8654 - val_loss: 0.6376 - val_accuracy: 0.8433
# Epoch 20/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5447 - accuracy: 0.8644 - val_loss: 0.5553 - val_accuracy: 0.8706
# Epoch 21/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5391 - accuracy: 0.8672 - val_loss: 0.5726 - val_accuracy: 0.8657
# Epoch 22/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5436 - accuracy: 0.8678 - val_loss: 0.6133 - val_accuracy: 0.8501
# Epoch 23/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5429 - accuracy: 0.8653 - val_loss: 0.6164 - val_accuracy: 0.8572
# Epoch 24/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5394 - accuracy: 0.8680 - val_loss: 0.5350 - val_accuracy: 0.8748
# Epoch 25/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5420 - accuracy: 0.8676 - val_loss: 0.5510 - val_accuracy: 0.8725
# Epoch 26/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5389 - accuracy: 0.8695 - val_loss: 0.5200 - val_accuracy: 0.8783
# Epoch 27/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5360 - accuracy: 0.8673 - val_loss: 0.6456 - val_accuracy: 0.8446
# Epoch 28/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5377 - accuracy: 0.8685 - val_loss: 0.5964 - val_accuracy: 0.8571
# Epoch 29/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5375 - accuracy: 0.8674 - val_loss: 0.5939 - val_accuracy: 0.8598
# Epoch 30/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5402 - accuracy: 0.8672 - val_loss: 0.6506 - val_accuracy: 0.8425
# Epoch 31/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5316 - accuracy: 0.8703 - val_loss: 0.5407 - val_accuracy: 0.8704
# Epoch 32/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5375 - accuracy: 0.8682 - val_loss: 0.5575 - val_accuracy: 0.8696
# Epoch 33/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5347 - accuracy: 0.8705 - val_loss: 0.5894 - val_accuracy: 0.8626
# Epoch 34/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5336 - accuracy: 0.8688 - val_loss: 0.6229 - val_accuracy: 0.8474
# Epoch 35/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5334 - accuracy: 0.8690 - val_loss: 0.5282 - val_accuracy: 0.8753
# Epoch 36/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5351 - accuracy: 0.8706 - val_loss: 0.5298 - val_accuracy: 0.8782
# Epoch 00036: early stopping

# %%
cifar10_c2f2.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3077 - accuracy: 0.1027
# [2.307710647583008, 0.10270000249147415]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# 중요
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f2_best_weights.026-0.8783.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f2_best_weights.026-0.8783.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5200 - accuracy: 0.8783
# [0.5199990272521973, 0.8783000111579895]

# %% [markdown]
# ## **CNN2 + FCN3**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c2f3 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 32, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(64, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c2f3.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cifar10_c2f3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_11 (Conv2D)          (None, 32, 32, 32)        896
#
#  max_pooling2d_8 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 4096)              0
#
#  dense_9 (Dense)             (None, 128)               524416
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 552,714
# Trainable params: 552,714
# Non-trainable params: 0
# _________________________________________________________________

# %%
mc_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c2f3_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=10)

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[mc_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 52s 51ms/step - loss: 0.5358 - accuracy: 0.8697 - val_loss: 0.6332 - val_accuracy: 0.8468
# Epoch 2/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5371 - accuracy: 0.8706 - val_loss: 0.5614 - val_accuracy: 0.8664
# Epoch 3/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5349 - accuracy: 0.8699 - val_loss: 0.6116 - val_accuracy: 0.8555
# Epoch 4/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5332 - accuracy: 0.8692 - val_loss: 0.6678 - val_accuracy: 0.8384
# Epoch 5/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5332 - accuracy: 0.8710 - val_loss: 0.5952 - val_accuracy: 0.8568
# Epoch 6/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5294 - accuracy: 0.8706 - val_loss: 0.6055 - val_accuracy: 0.8539
# Epoch 7/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5340 - accuracy: 0.8701 - val_loss: 0.5828 - val_accuracy: 0.8649
# Epoch 8/500
# 1000/1000 [==============================] - 53s 52ms/step - loss: 0.5324 - accuracy: 0.8691 - val_loss: 0.6209 - val_accuracy: 0.8542
# Epoch 9/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5355 - accuracy: 0.8702 - val_loss: 0.6035 - val_accuracy: 0.8608
# Epoch 10/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5336 - accuracy: 0.8694 - val_loss: 0.5774 - val_accuracy: 0.8668
# Epoch 11/500
# 1000/1000 [==============================] - 51s 51ms/step - loss: 0.5317 - accuracy: 0.8713 - val_loss: 0.5824 - val_accuracy: 0.8616
# Epoch 12/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5262 - accuracy: 0.8724 - val_loss: 0.5768 - val_accuracy: 0.8662
# Epoch 13/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5287 - accuracy: 0.8703 - val_loss: 0.5626 - val_accuracy: 0.8679
# Epoch 14/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5275 - accuracy: 0.8725 - val_loss: 0.5844 - val_accuracy: 0.8628
# Epoch 15/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5278 - accuracy: 0.8725 - val_loss: 0.5972 - val_accuracy: 0.8636
# Epoch 16/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5275 - accuracy: 0.8718 - val_loss: 0.5704 - val_accuracy: 0.8724
# Epoch 17/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5274 - accuracy: 0.8712 - val_loss: 0.5703 - val_accuracy: 0.8672
# Epoch 18/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5233 - accuracy: 0.8719 - val_loss: 0.5717 - val_accuracy: 0.8709
# Epoch 19/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5234 - accuracy: 0.8723 - val_loss: 0.6117 - val_accuracy: 0.8544
# Epoch 20/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5254 - accuracy: 0.8750 - val_loss: 0.5738 - val_accuracy: 0.8678
# Epoch 21/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5257 - accuracy: 0.8734 - val_loss: 0.5523 - val_accuracy: 0.8689
# Epoch 22/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5225 - accuracy: 0.8737 - val_loss: 0.5415 - val_accuracy: 0.8749
# Epoch 23/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5287 - accuracy: 0.8723 - val_loss: 0.5853 - val_accuracy: 0.8609
# Epoch 24/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5241 - accuracy: 0.8721 - val_loss: 0.5721 - val_accuracy: 0.8644
# Epoch 25/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5211 - accuracy: 0.8736 - val_loss: 0.5718 - val_accuracy: 0.8658
# Epoch 26/500
# 1000/1000 [==============================] - 53s 53ms/step - loss: 0.5213 - accuracy: 0.8741 - val_loss: 0.5697 - val_accuracy: 0.8678
# Epoch 27/500
# 1000/1000 [==============================] - 50s 50ms/step - loss: 0.5196 - accuracy: 0.8744 - val_loss: 0.5691 - val_accuracy: 0.8657
# Epoch 28/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5235 - accuracy: 0.8746 - val_loss: 0.6843 - val_accuracy: 0.8324
# Epoch 29/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5200 - accuracy: 0.8760 - val_loss: 0.5656 - val_accuracy: 0.8651
# Epoch 30/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5191 - accuracy: 0.8745 - val_loss: 0.6273 - val_accuracy: 0.8572
# Epoch 31/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5182 - accuracy: 0.8738 - val_loss: 0.6205 - val_accuracy: 0.8553
# Epoch 32/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5232 - accuracy: 0.8728 - val_loss: 0.5540 - val_accuracy: 0.8736
# Epoch 00032: early stopping

# %%
cifar10_c2f3.evaluate(X_test, y_test, batch_size =100)
# Out:
# 100/100 [==============================] - 1s 6ms/step - loss: 2.3041 - accuracy: 0.1131
# [2.3041036128997803, 0.11309999972581863]

# %% [markdown]
# ## Graph of loss and accuracy
# - model: cifar_c2f2_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
# vacc_list[np.argmax(np.array(vacc_list))]
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],4)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c2f3_Daug_best_weights.019-0.8726.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c2f3_Daug_best_weights.022-0.8749.hdf5')
model.evaluate(X_test, y_test, batch_size=100)
# Out:
# 100/100 [==============================] - 2s 13ms/step - loss: 0.5415 - accuracy: 0.8749
# [0.5415352582931519, 0.8748999834060669]

# %% [markdown]
# ## **CNN4 + FCN5**

# %%
cifar10_c4f5 = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3), filters= 64, kernel_size=(3,3),strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 128, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 256, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 512, kernel_size=(3,3), strides=(1,1), padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_Daug_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))                                 # 5번동안 더 높은 값이 나오지 않아서 stop
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 51s 50ms/step - loss: 0.5233 - accuracy: 0.8720 - val_loss: 0.5519 - val_accuracy: 0.8764
# Epoch 2/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5216 - accuracy: 0.8744 - val_loss: 0.5791 - val_accuracy: 0.8662
# Epoch 3/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5237 - accuracy: 0.8725 - val_loss: 0.6348 - val_accuracy: 0.8465
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5202 - accuracy: 0.8731 - val_loss: 0.5798 - val_accuracy: 0.8664
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5168 - accuracy: 0.8750 - val_loss: 0.5392 - val_accuracy: 0.8731
# Epoch 6/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5179 - accuracy: 0.8748 - val_loss: 0.5875 - val_accuracy: 0.8625
# Epoch 00006: early stopping

# %%
cifar10_c4f5.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 8ms/step - loss: 2.3029 - accuracy: 0.1023
# [2.3028788566589355, 0.1023000031709671]

# %% [markdown]
# # Graph of loss and accuracy
# - model: cifar10_c4f5_Daug

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_Daug_best_weights.001-0.8764.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 2s 11ms/step - loss: 0.5519 - accuracy: 0.8764
# [0.551943838596344, 0.8763999938964844]

# %% [markdown]
# # **c4f5 best model 구하기**

# %%
# Random number seed
np.random.seed(1234)
tf.random.set_seed(1234)

# %%
cifar10_c4f5_ = keras.models.Sequential([ 
    Conv2D(input_shape=(32,32,3),filters= 512, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)), 
    Conv2D(filters= 256, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 128, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Conv2D(filters= 64, 
                kernel_size=(3,3),strides=(1,1),padding='same',activation='relu'),
    MaxPool2D(pool_size=(2,2), strides=(2,2)),
    Flatten(), 
    keras.layers.Dense(128, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(256, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(512, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(1024, activation='relu'),  
    keras.layers.Dropout(0.25), 
    keras.layers.Dense(10, activation='softmax')
])

cifar10_c4f5_.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
cp_callback = callbacks.ModelCheckpoint(filepath="./cifar10_c4f5_best_weights.{epoch:03d}-{val_accuracy:.4f}.hdf5", 
                              monitor='val_accuracy', verbose=0, save_best_only=True)
es_callback = callbacks.EarlyStopping(monitor='val_accuracy', 
                            mode='max', verbose=1, patience=5)    # patience=10,20,50

# %%
epochs = 500
BATCH_SIZE = 50
hist = model.fit(datagen.flow(X_train, y_train, batch_size=BATCH_SIZE), 
                 steps_per_epoch=X_train.shape[0]//BATCH_SIZE, 
                 epochs=epochs, verbose=1, 
                 callbacks=[cp_callback, es_callback], 
                 validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 1000/1000 [==============================] - 52s 51ms/step - loss: 0.5213 - accuracy: 0.8746 - val_loss: 0.5912 - val_accuracy: 0.8604
# Epoch 2/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5197 - accuracy: 0.8745 - val_loss: 0.6004 - val_accuracy: 0.8578
# Epoch 3/500
# 1000/1000 [==============================] - 50s 49ms/step - loss: 0.5191 - accuracy: 0.8739 - val_loss: 0.6080 - val_accuracy: 0.8540
# Epoch 4/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5225 - accuracy: 0.8735 - val_loss: 0.6219 - val_accuracy: 0.8528
# Epoch 5/500
# 1000/1000 [==============================] - 52s 52ms/step - loss: 0.5179 - accuracy: 0.8753 - val_loss: 0.7140 - val_accuracy: 0.8325
# Epoch 6/500
# 1000/1000 [==============================] - 49s 49ms/step - loss: 0.5247 - accuracy: 0.8749 - val_loss: 0.6205 - val_accuracy: 0.8566
# Epoch 00006: early stopping

# %%
cifar10_c4f5_.evaluate(X_test, y_test, batch_size = BATCH_SIZE)
# Out:
# 200/200 [==============================] - 4s 15ms/step - loss: 2.3022 - accuracy: 0.1296
# [2.3022043704986572, 0.12960000336170197]

# %%
# Plot loass and accuracy
# Plot training & validation accuracy values
loss_list = [100 * i for i in hist.history['loss']]
acc_list = [100 * i for i in hist.history['accuracy']]

epochs = range(1, len(loss_list) + 1)

plt.plot(epochs,loss_list) 
plt.plot(epochs,acc_list) 
plt.title('Model loss & accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['loss', 'accuracy'], loc='center left')
plt.show()

# %%
vloss_list = [100 * i for i in hist.history['val_loss']]
vacc_list = [100 * i for i in hist.history['val_accuracy']]

# %%
plt.plot(epochs,vloss_list)  
plt.plot(epochs,vacc_list)  
plt.title('Model val_loss & val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['val_loss', 'val_accuracy'], loc='center left')
plt.show()

# %%
plt.plot(epochs,acc_list)  
plt.plot(epochs,vacc_list)  
plt.title('accuracy vs. val_accuracy')
plt.ylabel('Accuracy (%)')
plt.xlabel('Epoch')
plt.legend(['accuracy','val_accuracy'], loc='center')
plt.plot(np.argmax(np.array(vacc_list))+1,vacc_list[np.argmax(np.array(vacc_list))], 'r*') 
plt.show()

# %%
# More graphs of loss and accuracy
history_dict = hist.history
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)

plt.figure(figsize=(14, 4))

plt.subplot(1,2,1)
plt.plot(epochs, loss, 'go-', label='Training Loss')
plt.plot(epochs, val_loss, 'bd', label='Validation Loss')
plt.plot(np.argmin(np.array(val_loss))+1,val_loss[np.argmin(np.array(val_loss))], 'r*', ms=12)
plt.title('Training and Validation Loss, min: ' + str(np.round(val_loss[np.argmin(np.array(val_loss))],2)))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']

epochs = range(1, len(loss) + 1)

plt.subplot(1,2,2)
plt.plot(epochs, acc, 'go-', label='Training Accuracy') #, c='blue')
plt.plot(epochs, val_acc, 'bd', label='Validation Accuracy') #, c='red')
plt.plot(np.argmax(np.array(val_acc))+1,val_acc[np.argmax(np.array(val_acc))], 'r*', ms=12)
plt.title('Training and Validation Accuracy, max: ' + str(np.round(val_acc[np.argmax(np.array(val_acc))],4)))
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Best model
# - cifar10_c4f5_best_weights.001-0.8671.hdf5

# %%
from keras.models import load_model

model = load_model('cifar10_c4f5_best_weights.001-0.8604.hdf5')
model.evaluate(X_test, y_test, batch_size=50)
# Out:
# 200/200 [==============================] - 2s 10ms/step - loss: 0.5912 - accuracy: 0.8604
# [0.5911893844604492, 0.8604000210762024]

# %% [markdown]
# #** 결과 비교 **

# %%
result = [[0.7278996109962463, 0.8025000095367432], 
 [0.6284098625183105, 0.8384000062942505], 
 [0.5490110516548157, 0.8726000189781189], 
 [0.558661937713623, 0.868399977684021],
 [0.5652801990509033, 0.8671000003814697]]

# %%
accuracy = [row[1] for row in result]
accuracy
# Out:
# [0.8025000095367432,
#  0.8384000062942505,
#  0.8726000189781189,
#  0.868399977684021,
#  0.8671000003814697]

# %%
x = np.arange(5)
models = ['cifar10_Daug','cifar10_c1f3','cifar10_c2f2','cifar10_c4f5_Daug','cifar_c4f5']
accuracies = [acc*100 for acc in accuracy] # %

plt.figure(figsize=(10,5))
plt.bar(x, accuracies)
plt.xticks(x, models)
plt.show()

# %% [markdown]
# ## 모형의 저장
#
# - 트레이닝이 끝난 모형은 save 메서드로 가중치와 함께 hdf5 형식으로 저장
# - load 명령으로 불러 사용

# %% [markdown]
# ### Best Daug model
# - cifar10_Daug_best_weights.013-0.8025.hdf5
# - cifar10_c4f5_Daug_best_weights.001-0.8684.hdf5
# ### Best c4f5 model of cifar10
# - cifar10_c4f5_best_weights.001-0.8671.hdf5

# %%
from keras.models import load_model

model_best = load_model('cifar10_c4f5_best_weights.001-0.8604.hdf5')
model_best.evaluate(X_test, y_test, batch_size=BATCH_SIZE)
# Out:
# 200/200 [==============================] - 2s 10ms/step - loss: 0.5912 - accuracy: 0.8604
# [0.5911893844604492, 0.8604000210762024]

# %% [markdown]
# ---

# %%
from sklearn.metrics import confusion_matrix

predictions = model_best.predict(X_test)
predictions0 = np.argmax(predictions, axis=1)
cm = confusion_matrix(y_test0, predictions0)

# %%
import seaborn as sns
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=class_names, yticklabels=class_names, fmt='d', annot=True, cmap=plt.cm.coolwarm)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion matrix', fontsize=20)
plt.show()

# %% [markdown]
# ---
